# %%
import os
import sys
import nbimporter
from pathlib import Path

# Ensure current directory is on sys.path
sys.path.append(r'C:\Users\lucho\Documents\temp\template generator nine')
cwd = os.getcwd()
if cwd not in sys.path:
    sys.path.append(cwd)


from template_manager import template_selector
from patient_data_extraction import extract_patient_info,image_extractor,generate_motility_report,get_measure_table,get_measurements,get_mot_table,mot_extractor
from file_conversion import cargar_path
from aux_calculations import remove_signs,expand_dict_with_lists_inplace, convert_to_int,calc_e_e_stress,expand_dict_with_lists_inplace
from docx import Document
from docxtpl import DocxTemplate
from convert_docx_to_pdf import convert_a_word_to_pdf



def render_template(path)-> None:
    '''
    acepta un path y determina si es cardiaco o stress, si son estos extrae medidas, tratornos de motilidad y mapa polar
    Si no lo es, extrae solamente datos del paciente y las imagenes del archivo docx producido por el equipo vinno
    guarda la renderizaci'on en la misma carpeta donde estaba el docx para poder realizar una comparacion

    '''
    doc=Document(path)
    template,tipo=template_selector(path)
    info_pac= extract_patient_info(doc)
    image=image_extractor(doc,template,tipo=tipo)
    #guardo el save path con nombre tipo de estudio y fecha en la misma carpeta.
    save_path=str(path).rsplit('\\',1)[0]+f'\\{info_pac["Name"]} {tipo} {info_pac["Exam_Date"]}.docx'
    print(save_path)
    print(tipo)
    #Si es carotida solo van los datos del paciente
    if tipo in ['card','stress']:
        measurements_table=get_measure_table(doc)
        measurements_dic=get_measurements(measurements_table,info_pac['Gender'])
        if tipo =='stress':
            mot_table=get_mot_table(doc)
            mot=mot_extractor(mot_table)
            mot_report=generate_motility_report(mot)
            expand_dict_with_lists_inplace(measurements_dic) #preparo el dict para la fx calc_e_e_stress
            measurements_dic['E_e_rel'],measurements_dic['e_e_avg']=calc_e_e_stress(measurements_dic)

            context={**info_pac,**measurements_dic,'image': image['image'], 'mot': mot['mot'],**mot_report}

        else:
            context={**info_pac,**measurements_dic,'image': image['image']}

    else:
        context={**info_pac,'image': image['image']}
    template.render(context)
    template.save(save_path)
    print(f'informe {info_pac["Name"]} creado con exito')
    return save_path

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
lista_de_trabajo=cargar_path(r"C:\Users\lucho\Documents\temp\documentos")
# Out:
# Converted C:\Users\lucho\Documents\temp\documentos\[aniballopez]-[20250718004]-[9cf396f3-6f41-4b57-8c85-ae82a14c11df]\8_S1-6P_Lucho Card.Report.V3.doc to C:\Users\lucho\Documents\temp\documentos\[aniballopez]-[20250718004]-[9cf396f3-6f41-4b57-8c85-ae82a14c11df]\8_S1-6P_Lucho Card.Report.V3.docx
# Converted C:\Users\lucho\Documents\temp\documentos\[atilanomontenegro]-[20250314001]-[43e08d8f-311d-4fd6-a9a7-ecaadbe1cf62]\10_S1-6P_Lucho Card.Report.V3.doc to C:\Users\lucho\Documents\temp\documentos\[atilanomontenegro]-[20250314001]-[43e08d8f-311d-4fd6-a9a7-ecaadbe1cf62]\10_S1-6P_Lucho Card.Report.V3.docx
# Converted C:\Users\lucho\Documents\temp\documentos\[carloscastera]-[20250718002]-[2164aa22-097e-46a7-a2e7-47c1999987b2]\3_S1-6P_Lucho Card.Report.V3.doc to C:\Users\lucho\Documents\temp\documentos\[carloscastera]-[20250718002]-[2164aa22-097e-46a7-a2e7-47c1999987b2]\3_S1-6P_Lucho Card.Report.V3.docx
# Converted C:\Users\lucho\Documents\temp\documentos\[carloscastera]-[20250718002]-[2164aa22-097e-46a7-a2e7-47c1999987b2]\4_S1-6P_Lucho Card.Report.V3.doc to C:\Users\lucho\Documents\temp\documentos\[carloscastera]-[20250718002]-[2164aa22-097e-46a7-a2e7-47c1999987b2]\4_S1-6P_Lucho Card.Report.V3.docx
# Converted C:\Users\lucho\Documents\temp\documentos\[carloshuerta]-[20250718005]-[529e5469-51b1-4527-9c1a-5d91b38f0809]\9_S1-6P_Lucho Card.Report.V3.doc to C:\Users\lucho\Documents\temp\documentos\[carloshuerta]-[20250718005]-[529e5469-51b1-4527-9c1a-5d91b38f0809]\9_S1-6P_Lucho Card.Report.V3.docx
# Converted C:\Users\lucho\Documents\temp\documentos\[horacioinsaurralde]-[20250718001]-[bdd4fd0f-9656-47f8-aec3-b50d8ae6aaa2]\2_S1-6P_Lucho Card.Report.V3.doc to C:\Users\lucho\Documents\temp\documentos\[horacioinsaurralde]-[20250718001]-[bdd4fd0f-9656-47f8-aec3-b50d8ae6aaa2]\2_S1-6P_Lucho Card.Report.V3.docx
# Converted C:\Users\lucho\Documents\temp\documentos\[mariaarevali]-[20250718003]-[9f0a5de7-56d0-4aae-98ef-c8ac531e9c10]\5_S1-6P_Lucho Card.Report.V3.doc to C:\Users\lucho\Documents\temp\documentos\[mariaarevali]-[20250718003]-[9f0a5de7-56d0-4aae-98ef-c8ac531e9c10]\5_S1-6P_Lucho Card.Report.V3.docx
# Converted C:\Users\lucho\Documents\temp\documentos\[mariaarevali]-[20250718003]-[9f0a5de7-56d0-4aae-98ef-c8ac531e9c10]\6_S1-6P_Lucho Card.Report.V3.doc to C:\Users\lucho\Documents\temp\documentos\[mariaarevali]-[20250718003]-[9f0a5de7-56d0-4aae-98ef-c8ac531e9c10]\6_S1-6P_Lucho Card.Report.V3.docx
# Converted C:\Users\lucho\Documents\temp\documentos\[mariaarevali]-[20250718003]-[9f0a5de7-56d0-4aae-98ef-c8ac531e9c10]\7_S1-6P_Lucho Card.Report.V3.doc to C:\Users\lucho\Documents\temp\documentos\[mariaarevali]-[20250718003]-[9f0a5de7-56d0-4aae-98ef-c8ac531e9c10]\7_S1-6P_Lucho Card.Report.V3.docx
# Converted C:\Users\lucho\Documents\temp\documentos\[mariaperna]-[20250718000]-[ea48b61c-b49f-479a-b25c-4aeccb82b1cd]\1_S1-6P_Lucho Card.Report.V3.doc to C:\Users\lucho\Documents\temp\documentos\[mariaperna]-[20250718000]-[ea48b61c-b49f-479a-b25c-4aeccb82b1cd]\1_S1-6P_Lucho Card.Report.V3.docx
# Converted C:\Users\lucho\Documents\temp\documentos\[vicentelescano]-[20250307009]-[53bad1b0-d195-4ba5-855d-a946180b2e31]\11_S1-6P_Lucho Card.Report.V3.doc to C:\Users\lucho\Documents\temp\documentos\[vicentelescano]-[20250307009]-[53bad1b0-d195-4ba5-855d-a946180b2e31]\11_S1-6P_Lucho Card.Report.V3.docx

# %%
saved_paths=[]
for index,i in enumerate(lista_de_trabajo):
    print(f'archivo N {index}')
    saved_paths.append(render_template(i))

# error '>=' not supported between instances of 'list' and 'int' antoniorocco
# Out:
# archivo N 0
# C:\Users\lucho\Documents\temp\documentos\[aniballopez]-[20250718004]-[9cf396f3-6f41-4b57-8c85-ae82a14c11df]\lopez cesar anibal stress 18-07-2025.docx
# stress
# informe lopez cesar anibal creado con exito
# archivo N 1
# C:\Users\lucho\Documents\temp\documentos\[atilanomontenegro]-[20250314001]-[43e08d8f-311d-4fd6-a9a7-ecaadbe1cf62]\montenegro oracio atilano stress 11-07-2025.docx
# stress
# division by zero
# informe montenegro oracio atilano creado con exito
# archivo N 2
# C:\Users\lucho\Documents\temp\documentos\[carloscastera]-[20250718002]-[2164aa22-097e-46a7-a2e7-47c1999987b2]\castera juan carlos stress 18-07-2025.docx
# stress
# division by zero
# informe castera juan carlos creado con exito
# archivo N 3
# C:\Users\lucho\Documents\temp\documentos\[carloscastera]-[20250718002]-[2164aa22-097e-46a7-a2e7-47c1999987b2]\castera juan carlos stress 18-07-2025.docx
# stress
# division by zero
# informe castera juan carlos creado con exito
# archivo N 4
# C:\Users\lucho\Documents\temp\documentos\[carloshuerta]-[20250718005]-[529e5469-51b1-4527-9c1a-5d91b38f0809]\huerta juan carlos stress 18-07-2025.docx
# stress
# division by zero
# informe huerta juan carlos creado con exito
# archivo N 5
# C:\Users\lucho\Documents\temp\documentos\[horacioinsaurralde]-[20250718001]-[bdd4fd0f-9656-47f8-aec3-b50d8ae6aaa2]\insaurralde carlos horacio stress 18-07-2025.docx
# stress
# informe insaurralde carlos horacio creado con exito
# archivo N 6
# C:\Users\lucho\Documents\temp\documentos\[mariaarevali]-[20250718003]-[9f0a5de7-56d0-4aae-98ef-c8ac531e9c10]\arevali maria stress 18-07-2025.docx
# stress
# division by zero
# informe arevali maria creado con exito
# archivo N 7
# C:\Users\lucho\Documents\temp\documentos\[mariaarevali]-[20250718003]-[9f0a5de7-56d0-4aae-98ef-c8ac531e9c10]\arevali maria stress 18-07-2025.docx
# stress
# division by zero
# informe arevali maria creado con exito
# archivo N 8
# C:\Users\lucho\Documents\temp\documentos\[mariaarevali]-[20250718003]-[9f0a5de7-56d0-4aae-98ef-c8ac531e9c10]\arevali maria stress 18-07-2025.docx
# stress
# division by zero
# informe arevali maria creado con exito
# archivo N 9
# C:\Users\lucho\Documents\temp\documentos\[mariaperna]-[20250718000]-[ea48b61c-b49f-479a-b25c-4aeccb82b1cd]\perna estela maria stress 18-07-2025.docx
# stress
# informe perna estela maria creado con exito
# archivo N 10
# C:\Users\lucho\Documents\temp\documentos\[vicentelescano]-[20250307009]-[53bad1b0-d195-4ba5-855d-a946180b2e31]\lescano tomas vicente stress 11-07-2025.docx
# stress
# informe lescano tomas vicente creado con exito

# %% [markdown]
# # Convert docx to pdf

# %%
#convert to pdf
for file in saved_paths:
    convert_a_word_to_pdf(file)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from pathlib import Path
path=r"C:\Users\lucho\Documents\temp\documentos\[anthonycollins]-[20250515004]-[c4d44b2c-be4e-4c15-9bb3-59444c7a2122]\12_S1-6P_card2.Report.V3.docx"
path=Path(path)
render_template(path)

# %% [markdown]
# # Context dict:
#
# ## Patient data
#     {
#     'Name': str, 'Patient_ID': str,
#     'Age': str(edad)+ 'y', 'Gender': str,
#     'Exam_Date': str(mm-dd-yyyy),
#     'Perf.Physician': str,
#     'Ref.Physician': str,
#     'Operator': str
#     }
#
# ## Measurements (if more than one, list of the same type)
#     {
#     'CARD_card2_2D_General': None, 'IVC_Diam': mm float or list float,
#     'IVSd': mm int, 'LVIDd': mm int , 'LVPWd': mm int, 'IVSs': mm float, 'LVIDs': mm int, 'LVPWs': mm float,
#     'Ao_Diam': mm int, 'RAAd': diam cm2 int, 'Distance': mm int, 'LAAd': volume ml/m2 float,
#     'A4C_Simpson': % str, 'LVEDV': float ml, 'LVESV': float ml, 'LVAd': float cm2, 'LVLd': float cm2, 'LVAs': float,   'LVLs':float,
#     'CARD_card2_M_General': None, 'TAPSE': float mm,
#     'CARD_card2_Doppler_General': None,
#     'AV_Vmax': float m/seg, 'AV_Vmax_grad': float mmHg, 'PG': float mmHg,
#     'LVOT_Vmax': float m/seg, 'LVOT_Vmax_grad': float mmHg,
#     'MV_Vel_E': float m/seg, 'MV_Vel_E_grad': float mmHg, 'MV_Vel_A': float m/seg, 'MV_Vel_A_grad': float mmHg,
#     'Med_Vel_E': float cm/seg, 'Lat_Vel_E': float cm/seg, 'IVRT': float msec,
#     'Calculation_Item': 'Result', 'card2': None, 'FS_2D': % int, 'LVIDs_Index_2D': ml/m2 float, 'LVd_Mass_2D_ASE': float gr,
#     'LVd_Mass_Index_2D_ASE': int gr/m2, 'RWT_2D': dimless %, 'IVS_2D': 7.16, 'LVPW_2D': 1.12, 'LVESVI_A4C_Simp': float ml/m2, 'CSA_AV_SV': 7.61, 'MV_E_A_Ratio': float, 'AV_VR': float, 'E_Med_E': float, 'E_Lat_E': float, 'Average_E': float, 'E_Avg_E': float
#     }
#
# ## Image
#
#     { 'key': 'imageN',
#       'image': docxtpl.inline_image.InlineImage,
#       'key': 'imageN+1',
#       'image':docxtpl.inline_image.InlineImage,
#       ...
#     }
#
# ## MOT
#
#     {
#
#     }

# %% [markdown]
# # funcion para el GUI

# %%
import nbimporter
from template_manager import template_selector_gui

def render_template_gui(study_path,template_path)-> None:
    '''
    acepta un path y determina si es cardiaco o stress, si son estos extrae medidas, tratornos de motilidad y mapa polar
    Si no lo es, extrae solamente datos del paciente y las imagenes del archivo docx producido por el equipo vinno
    guarda la renderizaci'on en la misma carpeta donde estaba el docx para poder realizar una comparacion

    '''
    doc=Document(study_path)
    template,tipo=template_selector_gui(template_path,study_path)
    info_pac= extract_patient_info(doc)
    image=image_extractor(doc,template,tipo=tipo)
    #guardo el save path con nombre tipo de estudio y fecha en la misma carpeta.
    save_path=str(study_path).rsplit('\\',1)[0]+f'\\{info_pac["Name"]} {tipo} {info_pac["Exam_Date"]}.docx'
    #Si es carotida solo van los datos del paciente
    if tipo in ['card','stress']:
        measurements_table=get_measure_table(doc)
        measurements_dic=get_measurements(measurements_table,info_pac['Gender'])
        if tipo =='stress':
            mot_table=get_mot_table(doc)
            mot=mot_extractor(mot_table)
            mot_report=generate_motility_report(mot)
            expand_dict_with_lists_inplace(measurements_dic) #preparo el dict para la fx calc_e_e_stress
            measurements_dic['E_e_rel'],measurements_dic['e_e_avg']=calc_e_e_stress(measurements_dic)

            context={**info_pac,**measurements_dic,'image': image['image'], 'mot': mot['mot'],**mot_report}

        else:
            context={**info_pac,**measurements_dic,'image': image['image']}

    else:
        context={**info_pac,'image': image['image']}
    template.render(context)
    template.save(save_path)
    print(f'informe {info_pac["Name"]} creado con exito')

# %%
study_path=r"C:\Users\lucho\Documents\temp\documentos\[alcideslescano]-[20241230004]-[e4eda042-3275-48e6-ad59-bbf3de8797e2]\16_S1-6P_card2.Report.V3.docx"
template_path=r'C:\Users\lucho\Desktop\Plantillas'
render_template_gui(study_path,template_path)
